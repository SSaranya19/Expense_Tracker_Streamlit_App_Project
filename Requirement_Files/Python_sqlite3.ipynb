# %%
##Connecting Python to SQlite3

# %%
import sqlite3
import pandas as pd

# Read data from CSV
df = pd.read_csv('Expense_tracker.csv')
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%Y').dt.strftime('%Y-%m-%d')

# Connect to SQLite database
conn = sqlite3.connect('expense_db.db')
cursor = conn.cursor()

# Create the Expenses table
create_table_query = """
CREATE TABLE IF NOT EXISTS Expenses (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    Date DATE,
    Category TEXT,
    Payment_Mode TEXT,
    Description TEXT,
    Amount DECIMAL(10, 2),
    Cashback DECIMAL(10, 2)
);
"""
cursor.execute(create_table_query)

# Insert data into the table from the dataframe
for index, row in df.iterrows():
    insert_query = """
    INSERT INTO Expenses (Date, Category, Payment_Mode, Description, Amount, Cashback)
    VALUES (?, ?, ?, ?, ?, ?)
    """
    values = (row['Date'], row['Category'], row['Payment_Mode'], row['Description'], row['Amount'], row['Cashback'])
    cursor.execute(insert_query, values)

conn.commit()
print("Data inserted successfully!")
# Out:
# Data inserted successfully!

# %%
## Creating Queries

# %%
# 1. Total Expenses
select_query = "SELECT SUM(Amount) AS Total_Expense FROM expenses;"
cursor.execute(select_query)
rows = cursor.fetchall()
print(rows)
# Out:
# [(4901665.96,)]

# %%
# 2. Total number of transactions:
select_query = "SELECT COUNT(*) AS Total_transactions FROM Expenses;"
cursor.execute(select_query)
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (9600,)

# %%
# 3. First and last transaction date:
select_query = "SELECT MIN(Date) AS First_transaction, MAX(Date) AS Last_transaction FROM Expenses;"
cursor.execute(select_query)
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# ('2024-01-01', '2024-12-30')

# %%
# 4. Total, Avg, Min, Max Spending by Category:
select_query = "SELECT Category, SUM(Amount) AS Total_spent, Avg(Amount) AS Avg_spent, MAX(amount) AS Max_spent, MIN(amount) AS Min_spent FROM expenses GROUP BY Category ORDER BY Total_spent, Avg_spent, Max_spent, Min_spent;"
cursor.execute(select_query)
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# ('Medical Health', 659645.88, 489.3515430267062, 999.2, 15.72)
# ('Transportation', 672086.6, 506.08930722891563, 994.52, 14.53)
# ('Investment', 693521.32, 511.44640117994095, 993.88, 12.35)
# ('Shopping', 701044.16, 539.2647384615385, 998.73, 14.77)
# ('Entertainment', 718745.68, 495.00391184573004, 997.91, 14.62)
# ('Food', 722062.04, 524.7543895348838, 998.5, 21.89)
# ('Groceries', 734560.28, 510.1113055555556, 994.65, 11.38)

# %%
# 5. Transactions Count by Category:
select_query = "SELECT Category, COUNT(*) AS Total_trans FROM Expenses GROUP BY Category ORDER BY total_trans DESC;"
cursor.execute(select_query)
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# ('Entertainment', 1452)
# ('Groceries', 1440)
# ('Food', 1376)
# ('Investment', 1356)
# ('Medical Health', 1348)
# ('Transportation', 1328)
# ('Shopping', 1300)

# %%
# #6. Monthly Expenses:
select_query = "SELECT strftime('%Y-%m', Date) AS month, SUM(Amount) AS Total_spent FROM Expenses GROUP BY strftime('%Y-%m', Date) ORDER BY month;"
cursor.execute(select_query)
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# ('2024-01', 400472.88)
# ('2024-02', 424695.76)
# ('2024-03', 383321.2)
# ('2024-04', 419879.52)
# ('2024-05', 406339.88)
# ('2024-06', 389987.92)
# ('2024-07', 417089.2)
# ('2024-08', 408275.16)
# ('2024-09', 439198.72)
# ('2024-10', 409144.52)
# ('2024-11', 400858.8)
# ('2024-12', 402402.4)

# %%
# 7. Daily Expenses:
select_query = "SELECT DATE(date) AS Day, SUM(amount) AS Total_expenses FROM expenses GROUP BY DATE(date) ORDER BY day;"
cursor.execute(select_query)
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# ('2024-
# ('2024-12-15', 9409.84)
# ('2024-12-16', 14100.039999999999)
# ('2024-12-17', 12883.84)
# ('2024-12-18', 8800.36)
# ('2024-12-19', 11636.6)
# ('2024-12-20', 21284.72)
# ('2024-12-21', 18250.44)
# ('2024-12-22', 14984.24)
# ('2024-12-23', 7524.32)
# ('2024-12-24', 10970.08)
# ('2024-12-25', 10388.72)
# ('2024-12-26', 17602.44)
# ('2024-12-27', 15021.04)
# ('2024-12-28', 9508.12)
# ('2024-12-29', 14231.44)
# ('2024-12-30', 4017.72)

# %%
# 8. January month Expenses:
select_query = "SELECT * FROM Expenses WHERE strftime('%Y-%m', Date) = '2024-01' LIMIT 200;"
cursor.execute(select_query)
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (None, '2024-01-01', 'Food', 'Debit Card', 'Dinner delivery from zomato', 680.54, 0)
# (None, '2024-01-01', 'Shopping', 'UPI', 'Purchased electronics', 740.19, 0)
# (None, '2024-01-02', 'Shopping', 'UPI', 'Purchased electronics', 94.97, 0)
# (None, '2024-01-02', 'Entertainment', 'UPI', 'Gaming console purchase', 100.81, 0)
# (None, '2024-01-02', 'Transportation', 'Netbanking', 'Fuel refilled for the bike', 384.44, 0)
# (None, '2024-01-02', 'Transportation', 'Netbanking', 'Uber ride to the office', 231.5, 0)
# (None, '2024-01-02', 'Food', 'Debit Card', 'Had lunch at hotel', 943.08, 7.53)
# (None, '2024-01-02', 'Entertainment', 'Cash', 'Gaming console purchase', 268.43, 0)
# (None, '2024-01-03', 'Groceries', 'UPI', 'Grocery shopping at the local store', 241.53, 0)
# (None, '2024-01-03', 'Entertainment', 'Cash', 'Gaming console purchase', 688.75, 0)
# (None, '2024-01-03', 'Groceries', 'Cash', 'Purchased daily essentials', 402.69, 3.21)
# (None, '2024-01-03', 'Food', 'Netbanking', 'Had lunch at hotel', 785.06, 0)
# (None, '2024-01-03', 'Shopping', 'Debit Card', 'Bought household items', 860.42, 0)
# (None, '2024-01-03', 'Shopping', 'Netbanking', "Bought a gift for a friend's birthday", 818, 0)
# (None, '2024-01-03', 'Groceries', 'Credit Card', 'Bought fresh fruits and snacks', 863.83, 0)
# (None, '2024-01-03', 'Transportation', 'Debit Card', 'Bought a metro ticket for travel', 957.41, 0)
# (None, '2024-01-04', 'Medical Health', 'UPI', "Doctor's consultation fee", 479.32, 0)
# (None, '2024-01-04', 'Investment', 'Netbanking', 'Invested in stocks', 218.99, 7.58)
# (None, '2024-01-04', 'Shopping', 'Cash', 'Shopping for accessories', 669.85, 0)
# (None, '2024-01-04', 'Entertainment', 'Credit Card', 'Concert tickets', 376.33, 0)
# (None, '2024-01-04', 'Medical Health', 'UPI', "Doctor's consultation fee", 649.1, 0)
# (None, '2024-01-05', 'Transportation', 'Credit Card', 'Uber ride to the office', 618.76, 0)
# (None, '2024-01-05', 'Shopping', 'Debit Card', 'Shopping for accessories', 862.27, 0)
# (None, '2024-01-05', 'Food', 'Netbanking', 'Ordered food from swiggy', 769.51, 9.77)
# (None, '2024-01-05', 'Transportation', 'Debit Card', 'Paid for train ticket', 707.15, 0)
# (None, '2024-01-05', 'Medical Health', 'Credit Card', 'Medical insurance payment', 782.23, 0)
# (None, '2024-01-05', 'Medical Health', 'Netbanking', 'Health checkup cost', 327.24, 2.04)
# (None, '2024-01-06', 'Investment', 'Netbanking', 'Investment in gold', 294.39, 0)
# (None, '2024-01-06', 'Food', 'Netbanking', 'Had dinner at a restaurant with friends', 321.76, 0)
# (None, '2024-01-06', 'Investment', 'Netbanking', 'Invested in stocks', 982.06, 0)
# (None, '2024-01-07', 'Investment', 'Netbanking', 'Bought mutual fund units', 243.9, 6.06)
# (None, '2024-01-07', 'Shopping', 'UPI', "Bought a gift for a friend's birthday", 997.61, 6.1)
# (None, '2024-01-07', 'Food', 'UPI', 'Ordered food from swiggy', 607.43, 0)
# (None, '2024-01-07', 'Shopping', 'Cash', 'Bought household items', 606.09, 0)
# (None, '2024-01-07', 'Investment', 'Debit Card', 'Purchased bonds', 333.38, 3.24)
# (None, '2024-01-07', 'Entertainment', 'Credit Card', 'Movie tickets', 720.11, 5.14)
# (None, '2024-01-07', 'Entertainment', 'UPI', 'Gaming console purchase', 72.92, 0)
# (None, '2024-01-07', 'Investment', 'Netbanking', 'Purchased bonds', 198.22, 0)
# (None, '2024-01-07', 'Food', 'Cash', 'Dinner delivery from zomato', 939.58, 0)
# (None, '2024-01-07', 'Groceries', 'Debit Card', 'Purchased daily essentials', 204.89, 0)
# (None, '2024-01-08', 'Shopping', 'Cash', "Bought a gift for a friend's birthday", 644.48, 0)
# (None, '2024-01-08', 'Transportation', 'Netbanking', 'Fuel refilled for the bike', 470.56, 0)
# (None, '2024-01-08', 'Investment', 'Credit Card', 'Investment in gold', 212.2, 0)
# (None, '2024-01-08', 'Entertainment', 'UPI', 'Concert tickets', 928.66, 0)
# (None, '2024-01-08', 'Medical Health', 'UPI', "Doctor's consultation fee", 195.17, 0)
# (None, '2024-01-08', 'Investment', 'Netbanking', 'Bought mutual fund units', 337.19, 0)
# (None, '2024-01-08', 'Food', 'Debit Card', 'Dinner delivery from zomato', 998.5, 0)
# (None, '2024-01-08', 'Entertainment', 'UPI', 'Movie tickets', 462.17, 0)
# (None, '2024-01-08', 'Groceries', 'Credit Card', 'Grocery shopping at the local store', 125.58, 0)
# (None, '2024-01-09', 'Investment', 'Cash', 'Purchased bonds', 830.82, 0)
# (None, '2024-01-09', 'Investment', 'Netbanking', 'Investment in gold', 800.87, 0)
# (None, '2024-01-09', 'Shopping', 'Cash', "Bought a gift for a friend's birthday", 118.08, 0)
# (None, '2024-01-09', 'Food', 'Credit Card', 'Took out a meal from a restaurant', 436.1, 5.9)
# (None, '2024-01-09', 'Transportation', 'UPI', 'Paid for train ticket', 820.7, 0)
# (None, '2024-01-09', 'Food', 'Cash', 'Had dinner at a restaurant with friends', 355.71, 3.36)
# (None, '2024-01-09', 'Shopping', 'Cash', "Bought a gift for a friend's birthday", 18.88, 5.02)
# (None, '2024-01-09', 'Transportation', 'Credit Card', 'Bought a metro ticket for travel', 507.07, 0)
# (None, '2024-01-09', 'Transportation', 'Netbanking', 'Paid for a cab ride to work', 626.68, 0)
# (None, '2024-01-09', 'Shopping', 'Credit Card', 'Bought clothes', 21.63, 0)
# (None, '2024-01-09', 'Medical Health', 'Credit Card', 'Medical insurance payment', 157.01, 1.69)
# (None, '2024-01-09', 'Medical Health', 'Credit Card', "Doctor's consultation fee", 155.54, 0)
# (None, '2024-01-09', 'Entertainment', 'Cash', 'Gaming console purchase', 331.32, 0)
# (None, '2024-01-10', 'Food', 'Debit Card', 'Had dinner at a restaurant with friends', 113.44, 2.08)
# (None, '2024-01-10', 'Groceries', 'Debit Card', 'Bought fresh fruits and snacks', 422.41, 1.04)
# (None, '2024-01-10', 'Shopping', 'Netbanking', 'Bought household items', 631.44, 0.55)
# (None, '2024-01-10', 'Food', 'UPI', 'Had dinner at a restaurant with friends', 504.3, 0)
# (None, '2024-01-10', 'Investment', 'Cash', 'Purchased bonds', 550.08, 0)
# (None, '2024-01-10', 'Medical Health', 'Credit Card', 'Health checkup cost', 528.22, 0)
# (None, '2024-01-10', 'Groceries', 'Credit Card', 'Bought vegetables and fruits', 604.18, 0)
# (None, '2024-01-10', 'Entertainment', 'Netbanking', 'Gaming console purchase', 568.37, 0)
# (None, '2024-01-10', 'Groceries', 'Netbanking', 'Bought vegetables and fruits', 552.46, 0)
# (None, '2024-01-11', 'Transportation', 'Netbanking', 'Paid for a cab ride to work', 953.13, 0)
# (None, '2024-01-11', 'Transportation', 'Netbanking', 'Fuel refilled for the bike', 693.04, 0)
# (None, '2024-01-11', 'Medical Health', 'UPI', "Doctor's consultation fee", 303.96, 0)
# (None, '2024-01-11', 'Medical Health', 'Credit Card', 'Health checkup cost', 74.71, 0)
# (None, '2024-01-11', 'Groceries', 'Cash', 'Bought vegetables and fruits', 682.84, 0)
# (None, '2024-01-11', 'Medical Health', 'Cash', "Doctor's consultation fee", 329.15, 0)
# (None, '2024-01-12', 'Entertainment', 'Cash', 'Gaming console purchase', 847.97, 0)
# (None, '2024-01-12', 'Shopping', 'Debit Card', 'Purchased electronics', 650.75, 0)
# (None, '2024-01-12', 'Groceries', 'Debit Card', 'Grocery shopping at the local store', 795.25, 0)
# (None, '2024-01-12', 'Transportation', 'Credit Card', 'Bought a metro ticket for travel', 449.07, 0)
# (None, '2024-01-12', 'Shopping', 'Debit Card', 'Purchased electronics', 949.97, 0)
# (None, '2024-01-12', 'Transportation', 'Credit Card', 'Bought a metro ticket for travel', 517.59, 0)
# (None, '2024-01-12', 'Food', 'Credit Card', 'Dinner delivery from zomato', 354.61, 0)
# (None, '2024-01-12', 'Entertainment', 'Netbanking', 'Movie tickets', 556.04, 0)
# (None, '2024-01-12', 'Entertainment', 'Credit Card', 'Movie tickets', 38.76, 0)
# (None, '2024-01-13', 'Entertainment', 'Netbanking', 'Movie tickets', 329.45, 8.87)
# (None, '2024-01-13', 'Food', 'Credit Card', 'Dinner delivery from zomato', 602.59, 0)
# (None, '2024-01-13', 'Shopping', 'Debit Card', 'Purchased electronics', 51.66, 0)
# (None, '2024-01-13', 'Shopping', 'UPI', 'Bought household items', 119.24, 6.33)
# (None, '2024-01-13', 'Groceries', 'Credit Card', 'Bought vegetables and fruits', 241.99, 0)
# (None, '2024-01-13', 'Shopping', 'UPI', 'Bought household items', 105.99, 0)
# (None, '2024-01-14', 'Shopping', 'Cash', 'Shopping for accessories', 975.6, 0)
# (None, '2024-01-14', 'Investment', 'Netbanking', 'Invested in stocks', 115.46, 0)
# (None, '2024-01-14', 'Investment', 'Credit Card', 'Investment in gold', 730.11, 0)
# (None, '2024-01-14', 'Food', 'Cash', 'Dinner delivery from zomato', 817.88, 0)
# (None, '2024-01-14', 'Medical Health', 'Debit Card', "Doctor's consultation fee", 453.09, 0)
# (None, '2024-01-14', 'Groceries', 'Debit Card', 'Purchased daily essentials', 103.38, 0)
# (None, '2024-01-14', 'Groceries', 'Netbanking', 'Bought vegetables and fruits', 681.45, 0)
# (None, '2024-01-14', 'Medical Health', 'Cash', 'Health checkup cost', 858.19, 0)
# (None, '2024-01-14', 'Transportation', 'Debit Card', 'Fuel refilled for the bike', 254.83, 0)
# (None, '2024-01-14', 'Medical Health', 'Cash', 'Medical insurance payment', 812.46, 0)
# (None, '2024-01-14', 'Food', 'UPI', 'Had lunch at hotel', 545.58, 3.59)
# (None, '2024-01-15', 'Entertainment', 'Debit Card', 'Concert tickets', 885.17, 0)
# (None, '2024-01-15', 'Entertainment', 'Credit Card', 'Gaming console purchase', 242.26, 0)
# (None, '2024-01-15', 'Groceries', 'Cash', 'Purchased daily essentials', 483.61, 8.71)
# (None, '2024-01-16', 'Groceries', 'UPI', 'Bought vegetables and fruits', 280.46, 0)
# (None, '2024-01-16', 'Transportation', 'Netbanking', 'Uber ride to the office', 871.91, 0)
# (None, '2024-01-16', 'Groceries', 'Netbanking', 'Purchased daily essentials', 331.67, 0)
# (None, '2024-01-16', 'Investment', 'Cash', 'Bought mutual fund units', 97.73, 0)
# (None, '2024-01-17', 'Medical Health', 'Netbanking', 'Medical insurance payment', 610.45, 0)
# (None, '2024-01-17', 'Shopping', 'Debit Card', "Bought a gift for a friend's birthday", 588.72, 0)
# (None, '2024-01-17', 'Medical Health', 'Debit Card', 'Bought medication', 818.15, 0)
# (None, '2024-01-17', 'Investment', 'Netbanking', 'Purchased bonds', 941.15, 0)
# (None, '2024-01-17', 'Groceries', 'Cash', 'Bought fresh fruits and snacks', 810.77, 0)
# (None, '2024-01-17', 'Medical Health', 'Debit Card', 'Medical insurance payment', 396.56, 0)
# (None, '2024-01-17', 'Food', 'Debit Card', 'Took out a meal from a restaurant', 122.27, 0)
# (None, '2024-01-18', 'Medical Health', 'UPI', "Doctor's consultation fee", 908.65, 0)
# (None, '2024-01-18', 'Shopping', 'Debit Card', 'Bought household items', 558.84, 0)
# (None, '2024-01-18', 'Investment', 'Credit Card', 'Purchased bonds', 537.45, 0)
# (None, '2024-01-18', 'Shopping', 'UPI', 'Shopping for accessories', 545.66, 0)
# (None, '2024-01-18', 'Groceries', 'UPI', 'Bought vegetables and fruits', 571.61, 2.96)
# (None, '2024-01-18', 'Shopping', 'UPI', 'Bought clothes', 634.36, 0)
# (None, '2024-01-18', 'Transportation', 'Debit Card', 'Paid for a cab ride to work', 399.49, 3.43)
# (None, '2024-01-18', 'Investment', 'Credit Card', 'Investment in gold', 604.55, 0)
# (None, '2024-01-19', 'Entertainment', 'Credit Card', 'Concert tickets', 277.51, 0)
# (None, '2024-01-19', 'Investment', 'Debit Card', 'Invested in stocks', 840.56, 0)
# (None, '2024-01-19', 'Shopping', 'UPI', 'Bought household items', 881.29, 5.86)
# (None, '2024-01-19', 'Food', 'UPI', 'Dinner delivery from zomato', 513.62, 0)
# (None, '2024-01-20', 'Transportation', 'UPI', 'Paid for train ticket', 245.11, 0)
# (None, '2024-01-20', 'Groceries', 'Netbanking', 'Grocery shopping at the local store', 710.39, 0)
# (None, '2024-01-20', 'Shopping', 'Netbanking', "Bought a gift for a friend's birthday", 959.3, 0)
# (None, '2024-01-20', 'Investment', 'Debit Card', 'Bought mutual fund units', 593.49, 2.08)
# (None, '2024-01-20', 'Food', 'UPI', 'Had lunch at hotel', 234.28, 0)
# (None, '2024-01-20', 'Investment', 'Cash', 'Invested in stocks', 209.02, 2.94)
# (None, '2024-01-21', 'Investment', 'Netbanking', 'Bought mutual fund units', 625.1, 0)
# (None, '2024-01-21', 'Entertainment', 'Debit Card', 'Gaming console purchase', 712.33, 0)
# (None, '2024-01-21', 'Investment', 'UPI', 'Purchased bonds', 496.76, 0.66)
# (None, '2024-01-21', 'Groceries', 'Cash', 'Bought vegetables and fruits', 177.03, 0)
# (None, '2024-01-21', 'Transportation', 'Cash', 'Paid for a cab ride to work', 591.27, 0)
# (None, '2024-01-22', 'Groceries', 'Debit Card', 'Bought vegetables and fruits', 311.98, 0)
# (None, '2024-01-22', 'Entertainment', 'Cash', 'Movie tickets', 373.15, 0)
# (None, '2024-01-22', 'Food', 'Cash', 'Had dinner at a restaurant with friends', 65.59, 0)
# (None, '2024-01-22', 'Food', 'Cash', 'Dinner delivery from zomato', 268.45, 0)
# (None, '2024-01-22', 'Food', 'Credit Card', 'Ordered food from swiggy', 840.55, 0)
# (None, '2024-01-22', 'Medical Health', 'UPI', 'Health checkup cost', 580.83, 2.83)
# (None, '2024-01-22', 'Medical Health', 'Netbanking', 'Medical insurance payment', 73.81, 0)
# (None, '2024-01-22', 'Medical Health', 'Netbanking', 'Medical insurance payment', 71.42, 0)
# (None, '2024-01-23', 'Food', 'Cash', 'Took out a meal from a restaurant', 640.03, 0.75)
# (None, '2024-01-23', 'Entertainment', 'Netbanking', 'Movie tickets', 559.97, 7.57)
# (None, '2024-01-23', 'Shopping', 'Netbanking', 'Purchased electronics', 52.94, 0)
# (None, '2024-01-23', 'Food', 'Credit Card', 'Had lunch at hotel', 829.59, 9.87)
# (None, '2024-01-23', 'Medical Health', 'UPI', 'Medical insurance payment', 500.96, 0)
# (None, '2024-01-23', 'Transportation', 'Credit Card', 'Paid for train ticket', 657.77, 0)
# (None, '2024-01-23', 'Food', 'Cash', 'Had lunch at hotel', 484.24, 0.28)
# (None, '2024-01-24', 'Groceries', 'Credit Card', 'Grocery shopping at the local store', 764.69, 0)
# (None, '2024-01-24', 'Entertainment', 'Cash', 'Movie tickets', 240.74, 0)
# (None, '2024-01-24', 'Investment', 'Cash', 'Bought mutual fund units', 706.44, 0)
# (None, '2024-01-24', 'Food', 'UPI', 'Ordered food from swiggy', 517.65, 0)
# (None, '2024-01-24', 'Entertainment', 'Netbanking', 'Gaming console purchase', 753.05, 0)
# (None, '2024-01-24', 'Medical Health', 'Credit Card', 'Health checkup cost', 213.18, 0)
# (None, '2024-01-24', 'Shopping', 'UPI', 'Bought clothes', 786.58, 0)
# (None, '2024-01-24', 'Entertainment', 'UPI', 'Movie tickets', 269.22, 6.14)
# (None, '2024-01-25', 'Medical Health', 'Credit Card', 'Health checkup cost', 728.92, 0)
# (None, '2024-01-25', 'Entertainment', 'Debit Card', 'Gaming console purchase', 252.97, 0)
# (None, '2024-01-25', 'Shopping', 'Netbanking', 'Bought household items', 795.41, 0)
# (None, '2024-01-25', 'Entertainment', 'Netbanking', 'Concert tickets', 512.65, 0)
# (None, '2024-01-25', 'Groceries', 'Credit Card', 'Bought fresh fruits and snacks', 274.98, 8.63)
# (None, '2024-01-25', 'Entertainment', 'Credit Card', 'Movie tickets', 681.27, 6.3)
# (None, '2024-01-25', 'Transportation', 'Debit Card', 'Uber ride to the office', 449.76, 0)
# (None, '2024-01-25', 'Groceries', 'Credit Card', 'Bought fresh fruits and snacks', 418.17, 0)
# (None, '2024-01-25', 'Groceries', 'Cash', 'Purchased daily essentials', 165.65, 0)
# (None, '2024-01-25', 'Food', 'Cash', 'Dinner delivery from zomato', 610.2, 0)
# (None, '2024-01-25', 'Medical Health', 'Cash', 'Medical insurance payment', 964.45, 0)
# (None, '2024-01-26', 'Transportation', 'Netbanking', 'Paid for train ticket', 742.18, 0)
# (None, '2024-01-26', 'Transportation', 'Netbanking', 'Bought a metro ticket for travel', 52.68, 0)
# (None, '2024-01-26', 'Transportation', 'Credit Card', 'Paid for train ticket', 662.29, 0)
# (None, '2024-01-27', 'Entertainment', 'Debit Card', 'Concert tickets', 356.2, 0)
# (None, '2024-01-27', 'Shopping', 'Netbanking', 'Bought clothes', 524.63, 0)
# (None, '2024-01-27', 'Investment', 'UPI', 'Investment in gold', 902.96, 0)
# (None, '2024-01-28', 'Transportation', 'Cash', 'Uber ride to the office', 674.78, 0)
# (None, '2024-01-28', 'Shopping', 'Credit Card', 'Purchased electronics', 779.04, 0)
# (None, '2024-01-28', 'Transportation', 'UPI', 'Fuel refilled for the bike', 678.65, 0)
# (None, '2024-01-28', 'Entertainment', 'Credit Card', 'Concert tickets', 740.02, 0)
# (None, '2024-01-28', 'Food', 'Debit Card', 'Took out a meal from a restaurant', 234.48, 0)
# (None, '2024-01-29', 'Transportation', 'Debit Card', 'Uber ride to the office', 564.87, 0)
# (None, '2024-01-29', 'Groceries', 'UPI', 'Bought fresh fruits and snacks', 169.66, 0)
# (None, '2024-01-29', 'Entertainment', 'Cash', 'Gaming console purchase', 197.67, 0)
# (None, '2024-01-29', 'Entertainment', 'Debit Card', 'Movie tickets', 14.62, 0)
# (None, '2024-01-30', 'Transportation', 'Netbanking', 'Paid for a cab ride to work', 456.03, 0)
# (None, '2024-01-30', 'Entertainment', 'Netbanking', 'Gaming console purchase', 561.41, 0)
# (None, '2024-01-30', 'Transportation', 'Debit Card', 'Uber ride to the office', 90.5, 0)
# (None, '2024-01-30', 'Investment', 'Credit Card', 'Invested in stocks', 179.5, 0)
# (None, '2024-01-30', 'Medical Health', 'Netbanking', "Doctor's consultation fee", 759.66, 8.32)
# (None, '2024-01-30', 'Transportation', 'UPI', 'Uber ride to the office', 136.58, 0)
# (None, '2024-01-30', 'Groceries', 'UPI', 'Grocery shopping at the local store', 137.28, 0)
# (None, '2024-01-30', 'Entertainment', 'Debit Card', 'Movie tickets', 956.55, 7.73)
# (None, '2024-01-30', 'Groceries', 'Cash', 'Purchased daily essentials', 124.37, 3.56)
# (None, '2024-01-30', 'Transportation', 'Cash', 'Fuel refilled for the bike', 80.54, 0)
# (None, '2024-01-30', 'Food', 'Cash', 'Took out a meal from a restaurant', 544.91, 0)

# %%
# 9. Total cashback receive per month:
select_query = "SELECT strftime('%Y-%m', Date) AS Month, SUM(Cashback) AS Total_cashback FROM Expenses GROUP BY Month ORDER BY Month;"
cursor.execute(select_query)
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# ('2024-01', 710.88)
# ('2024-02', 444.16)
# ('2024-03', 531.72)
# ('2024-04', 389.56)
# ('2024-05', 380.52)
# ('2024-06', 381.76)
# ('2024-07', 384.96000000000004)
# ('2024-08', 570.84)
# ('2024-09', 409.48)
# ('2024-10', 341.71999999999997)
# ('2024-11', 653.88)
# ('2024-12', 247.48)

# %%
# 10. Total cashback receive per day:
select_query = "SELECT Date, SUM(Cashback) AS Total_cashback FROM Expenses GROUP BY Date ORDER BY Date;"
cursor.execute(select_query)
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# ('2024-01-01', 0)
# ('2024-01-02', 30.12)
# ('2024-01-03', 12.84)
# ('2024-01-04', 30.32)
# ('2024-01-05', 47.239999999999995)
# ('2024-01-06', 0)
# ('2024-01-07', 82.16)
# ('2024-01-08', 0)
# ('2024-01-09', 63.879999999999995)
# ('2024-01-10', 14.68)
# ('2024-01-11', 0)
# ('2024-01-12', 0)
# ('2024-01-13', 60.8)
# ('2024-01-14', 14.36)
# ('2024-01-15', 34.84)
# ('2024-01-16', 0)
# ('2024-01-17', 0)
# ('2024-01-18', 25.560000000000002)
# ('2024-01-19', 23.44)
# ('2024-01-20', 20.08)
# ('2024-01-21', 2.64)
# ('2024-01-22', 11.32)
# ('2024-01-23', 73.88)
# ('2024-11-25', 4.72)
# ('2024-11-26', 32.92)
# ('2024-11-27', 79.47999999999999)
# ('2024-11-28', 0)
# ('2024-11-29', 0)
# ('2024-12-01', 0)
# ('2024-12-02', 30.76)
# ('2024-12-03', 0)
# ('2024-12-04', 3.88)
# ('2024-12-05', 2.24)
# ('2024-12-06', 0)
# ('2024-12-07', 24.6)
# ('2024-12-08', 0)
# ('2024-12-09', 33.12)
# ('2024-12-10', 16.04)
# ('2024-12-11', 21.36)
# ('2024-12-12', 0)
# ('2024-12-13', 0)
# ('2024-12-14', 3.4)
# ('2024-12-15', 0)
# ('2024-12-16', 0)
# ('2024-12-17', 0)
# ('2024-12-18', 4.16)
# ('2024-12-19', 0)
# ('2024-12-20', 25.439999999999998)
# ('2024-12-21', 0)
# ('2024-12-22', 0)
# ('2024-12-23', 0)
# ('2024-12-24', 17.2)
# ('2024-12-25', 38.84)
# ('2024-12-26', 0)
# ('2024-12-27', 25.6)
# ('2024-12-28', 0)
# ('2024-12-29', 0.84)
# ('2024-12-30', 0)

# %%
# 11. Total, Avg, Min, Max spending by payment mode:
select_query = "SELECT Payment_Mode, SUM(Amount) AS Total_spent, Avg(Amount) AS Avg_spent, MAX(amount) AS Max_spent, MIN(amount) AS Min_spent FROM Expenses GROUP BY Payment_Mode ORDER BY Total_spent, Avg_spent, Max_spent, Min_spent;"
cursor.execute(select_query)
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# ('UPI', 879766.44, 488.7591333333333, 997.61, 14.53)
# ('Credit Card', 969947.8, 514.8342887473461, 996.06, 11.38)
# ('Cash', 991085.2, 502.5787018255578, 999.2, 13.36)
# ('Netbanking', 1013243.32, 504.6032470119522, 998.37, 21.84)
# ('Debit Card', 1047623.2, 541.1276859504133, 998.73, 14.62)

# %%
# 12. Count of transactions by payment mode:
select_query = "SELECT Payment_Mode, COUNT(*) AS Transaction_count FROM Expenses GROUP BY Payment_Mode ORDER BY transaction_count DESC;"
cursor.execute(select_query)
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# ('Netbanking', 2008)
# ('Cash', 1972)
# ('Debit Card', 1936)
# ('Credit Card', 1884)
# ('UPI', 1800)

# %%
# 13. Total cashback receive:
select_query = "SELECT SUM(Cashback) AS total_cashback FROM Expenses;"
cursor.execute(select_query)
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (5446.96,)

# %%
# 14. Avg, Max, Min cashback receive in each transaction:
select_query = "SELECT AVG(Cashback) AS Avg_cashback, MAX(Cashback) AS Max_cashback, MIN(Cashback) AS Min_cashback FROM Expenses;"
cursor.execute(select_query)
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (0.5673916666666666, 9.97, 0)

# %%
# 15. Total cashback by payment mode:
select_query = "SELECT Payment_Mode, SUM(Cashback) AS Total_cashback FROM Expenses GROUP BY Payment_Mode ORDER BY total_cashback;"
cursor.execute(select_query)
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# ('Cash', 111.32000000000001)
# ('Netbanking', 203.04)
# ('Credit Card', 1453.76)
# ('UPI', 1671.76)
# ('Debit Card', 2007.08)

# %%
# 16. Total spending after cashback:
select_query = "SELECT SUM(Amount - Cashback) AS Total_spent_after_cashback FROM Expenses;"
cursor.execute(select_query)
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (4896219.0,)

# %%
# 17. Total spending after cashback for Each Category:
select_query = "SELECT Category, SUM(Amount - Cashback) AS Total_spent_after_cashback FROM Expenses GROUP BY Category ORDER BY Total_spent_after_cashback DESC;"
cursor.execute(select_query)
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# ('Groceries', 733785.44)
# ('Food', 721291.36)
# ('Entertainment', 717864.5599999999)
# ('Shopping', 700360.76)
# ('Investment', 692724.4)
# ('Transportation', 671515.4)
# ('Medical Health', 658677.08)

# %%
# 18. Total cashback receive for each category:
select_query = "SELECT Category, SUM(Cashback) AS Total_cashback FROM Expenses GROUP BY Category ORDER BY total_cashback DESC;"
cursor.execute(select_query)
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# ('Medical Health', 968.8)
# ('Entertainment', 881.12)
# ('Investment', 796.92)
# ('Groceries', 774.84)
# ('Food', 770.68)
# ('Shopping', 683.4)
# ('Transportation', 571.2)

# %%
# 19. Month-Wise Count of Transactions for Each Category:
select_query = "SELECT strftime('%Y-%m', Date) AS Month, Category, COUNT(*) AS Transaction_count FROM Expenses GROUP BY Month, Category ORDER BY Month, Transaction_count DESC;"
cursor.execute(select_query)
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# ('2024-01', 'Entertainment', 128)
# ('2024-01', 'Transportation', 120)
# ('2024-01', 'Shopping', 120)
# ('2024-01', 'Food', 116)
# ('2024-01', 'Groceries', 112)
# ('2024-01', 'Medical Health', 104)
# ('2024-01', 'Investment', 100)
# ('2024-02', 'Medical Health', 160)
# ('2024-02', 'Groceries', 124)
# ('2024-02', 'Entertainment', 124)
# ('2024-02', 'Transportation', 100)
# ('2024-02', 'Investment', 100)
# ('2024-02', 'Food', 100)
# ('2024-02', 'Shopping', 92)
# ('2024-03', 'Investment', 136)
# ('2024-03', 'Groceries', 136)
# ('2024-03', 'Medical Health', 116)
# ('2024-03', 'Food', 116)
# ('2024-03', 'Transportation', 108)
# ('2024-03', 'Entertainment', 100)
# ('2024-03', 'Shopping', 88)
# ('2024-04', 'Investment', 140)
# ('2024-04', 'Food', 132)
# ('2024-04', 'Shopping', 116)
# ('2024-04', 'Groceries', 116)
# ('2024-04', 'Transportation', 112)
# ('2024-04', 'Entertainment', 96)
# ('2024-04', 'Medical Health', 88)
# ('2024-05', 'Shopping', 156)
# ('2024-05', 'Entertainment', 140)
# ('2024-05', 'Food', 124)
# ('2024-05', 'Medical Health', 112)
# ('2024-05', 'Investment', 104)
# ('2024-05', 'Groceries', 96)
# ('2024-05', 'Transportation', 68)
# ('2024-06', 'Groceries', 152)
# ('2024-06', 'Entertainment', 124)
# ('2024-06', 'Transportation', 120)
# ('2024-06', 'Investment', 120)
# ('2024-06', 'Medical Health', 112)
# ('2024-06', 'Shopping', 88)
# ('2024-06', 'Food', 84)
# ('2024-07', 'Food', 144)
# ('2024-07', 'Groceries', 128)
# ('2024-07', 'Transportation', 124)
# ('2024-07', 'Entertainment', 124)
# ('2024-07', 'Investment', 108)
# ('2024-07', 'Shopping', 88)
# ('2024-07', 'Medical Health', 84)
# ('2024-08', 'Entertainment', 140)
# ('2024-08', 'Investment', 136)
# ('2024-08', 'Food', 128)
# ('2024-08', 'Shopping', 104)
# ('2024-08', 'Medical Health', 104)
# ('2024-08', 'Transportation', 96)
# ('2024-08', 'Groceries', 92)
# ('2024-09', 'Transportation', 152)
# ('2024-09', 'Food', 152)
# ('2024-09', 'Groceries', 128)
# ('2024-09', 'Shopping', 120)
# ('2024-09', 'Medical Health', 88)
# ('2024-09', 'Investment', 88)
# ('2024-09', 'Entertainment', 72)
# ('2024-10', 'Entertainment', 136)
# ('2024-10', 'Medical Health', 132)
# ('2024-10', 'Shopping', 124)
# ('2024-10', 'Groceries', 120)
# ('2024-10', 'Investment', 112)
# ('2024-10', 'Transportation', 92)
# ('2024-10', 'Food', 84)
# ('2024-11', 'Medical Health', 148)
# ('2024-11', 'Groceries', 140)
# ('2024-11', 'Entertainment', 132)
# ('2024-11', 'Transportation', 116)
# ('2024-11', 'Investment', 100)
# ('2024-11', 'Shopping', 92)
# ('2024-11', 'Food', 72)
# ('2024-12', 'Entertainment', 136)
# ('2024-12', 'Food', 124)
# ('2024-12', 'Transportation', 120)
# ('2024-12', 'Shopping', 112)
# ('2024-12', 'Investment', 112)
# ('2024-12', 'Medical Health', 100)
# ('2024-12', 'Groceries', 96)

# %%
# 20. Count of transactions by Description:
select_query = "SELECT Description, COUNT(*) AS count FROM Expenses GROUP BY Description ORDER BY count DESC;"
cursor.execute(select_query)
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# ('Concert tickets', 524)
# ('Gaming console purchase', 504)
# ('Movie tickets', 424)
# ('Bought vegetables and fruits', 400)
# ('Invested in stocks', 376)
# ('Bought medication', 364)
# ('Bought fresh fruits and snacks', 364)
# ('Grocery shopping at the local store', 344)
# ('Bought mutual fund units', 340)
# ('Medical insurance payment', 336)
# ('Purchased daily essentials', 332)
# ('Purchased bonds', 328)
# ("Doctor's consultation fee", 328)
# ('Health checkup cost', 320)
# ('Dinner delivery from zomato', 320)
# ('Investment in gold', 312)
# ('Uber ride to the office', 304)
# ('Ordered food from swiggy', 288)
# ('Took out a meal from a restaurant', 280)
# ("Bought a gift for a friend's birthday", 280)
# ('Purchased electronics', 276)
# ('Paid for train ticket', 276)
# ('Fuel refilled for the bike', 276)
# ('Shopping for accessories', 260)
# ('Paid for a cab ride to work', 256)
# ('Had dinner at a restaurant with friends', 248)
# ('Bought clothes', 244)
# ('Had lunch at hotel', 240)
# ('Bought household items', 240)
# ('Bought a metro ticket for travel', 216)

# %%
# 21. Category wise highest spending in each month:
select_query = "SELECT strftime('%Y-%m', Date) AS Month, Category, SUM(Amount) AS Total_spent FROM Expenses GROUP BY Month, Category ORDER BY Month, Total_spent DESC;"
cursor.execute(select_query)
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# ('2024-01', 'Shopping', 68175.56)
# ('2024-01', 'Food', 62726.12)
# ('2024-01', 'Transportation', 62185.36)
# ('2024-01', 'Entertainment', 59507.4)
# ('2024-01', 'Medical Health', 50929.72)
# ('2024-01', 'Investment', 50329.52)
# ('2024-01', 'Groceries', 46619.200000000004)
# ('2024-02', 'Medical Health', 79923.08)
# ('2024-02', 'Groceries', 73806.36)
# ('2024-02', 'Entertainment', 72779.48)
# ('2024-02', 'Shopping', 52654.04)
# ('2024-02', 'Food', 50343.2)
# ('2024-02', 'Investment', 49928.479999999996)
# ('2024-02', 'Transportation', 45261.12)
# ('2024-03', 'Investment', 69978.4)
# ('2024-03', 'Food', 61428.04)
# ('2024-03', 'Groceries', 59581.24)
# ('2024-03', 'Medical Health', 52145.56)
# ('2024-03', 'Shopping', 50624.96)
# ('2024-03', 'Transportation', 47905.68)
# ('2024-03', 'Entertainment', 41657.32)
# ('2024-04', 'Food', 74863.2)
# ('2024-04', 'Investment', 71484.64)
# ('2024-04', 'Shopping', 68721.16)
# ('2024-04', 'Groceries', 57304.76)
# ('2024-04', 'Transportation', 55706.12)
# ('2024-04', 'Entertainment', 50117.56)
# ('2024-04', 'Medical Health', 41682.08)
# ('2024-05', 'Shopping', 84983.6)
# ('2024-05', 'Entertainment', 66224.12)
# ('2024-05', 'Food', 63488.6)
# ('2024-05', 'Medical Health', 56333.52)
# ('2024-05', 'Groceries', 53904.68)
# ('2024-05', 'Investment', 48364.88)
# ('2024-05', 'Transportation', 33040.48)
# ('2024-06', 'Groceries', 77615.96)
# ('2024-06', 'Transportation', 65410.76)
# ('2024-06', 'Investment', 60462.92)
# ('2024-06', 'Entertainment', 55077.8)
# ('2024-06', 'Medical Health', 45898.2)
# ('2024-06', 'Shopping', 43267.8)
# ('2024-06', 'Food', 42254.48)
# ('2024-07', 'Food', 86202.0)
# ('2024-07', 'Groceries', 65444.2)
# ('2024-07', 'Entertainment', 63327.56)
# ('2024-07', 'Investment', 58215.08)
# ('2024-07', 'Transportation', 53334.36)
# ('2024-07', 'Medical Health', 45342.72)
# ('2024-07', 'Shopping', 45223.28)
# ('2024-08', 'Investment', 66973.48)
# ('2024-08', 'Entertainment', 64726.12)
# ('2024-08', 'Food', 61404.32)
# ('2024-08', 'Medical Health', 58524.36)
# ('2024-08', 'Transportation', 57089.12)
# ('2024-08', 'Shopping', 56152.12)
# ('2024-08', 'Groceries', 43405.64)
# ('2024-09', 'Transportation', 86358.36)
# ('2024-09', 'Food', 72525.88)
# ('2024-09', 'Shopping', 70779.32)
# ('2024-09', 'Groceries', 69396.4)
# ('2024-09', 'Investment', 53656.44)
# ('2024-09', 'Medical Health', 45228.64)
# ('2024-09', 'Entertainment', 41253.68)
# ('2024-10', 'Entertainment', 73719.48)
# ('2024-10', 'Groceries', 63832.2)
# ('2024-10', 'Shopping', 62685.799999999996)
# ('2024-10', 'Medical Health', 60288.08)
# ('2024-10', 'Investment', 52343.76)
# ('2024-10', 'Transportation', 51774.68)
# ('2024-10', 'Food', 44500.52)
# ('2024-11', 'Medical Health', 76619.28)
# ('2024-11', 'Groceries', 75826.48)
# ('2024-11', 'Entertainment', 62204.44)
# ('2024-11', 'Transportation', 61139.24)
# ('2024-11', 'Investment', 47328.8)
# ('2024-11', 'Shopping', 44633.32)
# ('2024-11', 'Food', 33107.24)
# ('2024-12', 'Food', 69218.44)
# ('2024-12', 'Entertainment', 68150.72)
# ('2024-12', 'Investment', 64454.92)
# ('2024-12', 'Shopping', 53143.2)
# ('2024-12', 'Transportation', 52881.32)
# ('2024-12', 'Groceries', 47823.16)
# ('2024-12', 'Medical Health', 46730.64)
